# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importatation des donnees
# au dessous on va utilse pandas pour manipuler cette dataset donc on veut lire à partir d'un fichier csv

# %%
data=pd.read_csv('Data.csv')

# %% [markdown]
# au dessous on va voir demention de la dataset (ligne,colone)

# %%
data.shape
# Out:
# (5110, 12)

# %% [markdown]
# au dessous on va utilse la fonction head() pour lire les cinq premier elements et on peut parametrer

# %%
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# on peut afficher dés le debut jusqu'a les 5 dernier elements

# %%
data.head(-5)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5100  68398    Male  82.0             1              0          Yes
# 5101  36901  Female  45.0             0              0          Yes
# 5102  45010  Female  57.0             0              0          Yes
# 5103  22127  Female  18.0             0              0           No
# 5104  14180  Female  13.0             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# # Exploration des donnees
# au dessous on va utilse la fonction describe() pour consulter cette dataset on donne (le moyenne max min procentage std)

# %%
data.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %% [markdown]
# au dessous on va utilse extraire average glugose less than 140000000 ==> normal

# %%
data.loc[data["avg_glucose_level"]<=140000000]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# au dessous on va utilse extraire average glugose between 140000000 and 199000000 ==> prediabete

# %%
data.loc[(data["avg_glucose_level"]>=140000000) & (data["avg_glucose_level"]<=199000000)]
# Out:
# Empty DataFrame
# Columns: [id, gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %% [markdown]
# voir si les elts de meme type

# %%
data.count()
# Out:
# id                   5110
# gender               5110
# age                  5110
# hypertension         5110
# heart_disease        5110
# ever_married         5110
# work_type            5110
# Residence_type       5110
# avg_glucose_level    5110
# bmi                  4909
# smoking_status       5110
# stroke               5110
# dtype: int64

# %% [markdown]
# elts avait falsse donc n'avait pas des valeur manque au dessous

# %%
data.isnull()
# Out:
#          id  gender    age  hypertension  heart_disease  ever_married  \
# 0     False   False  False         False          False         False
# 1     False   False  False         False          False         False
# 2     False   False  False         False          False         False
# 3     False   False  False         False          False         False
# 4     False   False  False         False          False         False
# ...     ...     ...    ...           ...            ...           ...
# 5105  False   False  False         False          False         False
# 5106  False   False  False         False          False         False
# 5107  False   False  False         False          False         False
# 5108  False   False  False         False          False         False
# 5109  False   False  False         False          False         False
#
#       work_type  Residence_type  avg_glucose_level    bmi  smoking_status  \
# ...

# %% [markdown]
# au dessous on count valeur manquant

# %%
data.isnull().count()
# Out:
# id                   5110
# gender               5110
# age                  5110
# hypertension         5110
# heart_disease        5110
# ever_married         5110
# work_type            5110
# Residence_type       5110
# avg_glucose_level    5110
# bmi                  5110
# smoking_status       5110
# stroke               5110
# dtype: int64

# %% [markdown]
# au dessous on listé les colones à des valeur manquant

# %%
data.columns[data.isnull().any()]
# Out:
# Index(['bmi'], dtype='object')

# %% [markdown]
# au dessous on listé les valeur manquant par colones

# %%
data.isnull().count()
# Out:
# id                   5110
# gender               5110
# age                  5110
# hypertension         5110
# heart_disease        5110
# ever_married         5110
# work_type            5110
# Residence_type       5110
# avg_glucose_level    5110
# bmi                  5110
# smoking_status       5110
# stroke               5110
# dtype: int64

# %% [markdown]
# Madame ces deux derniers commande non coherente puisque "data.columns[data.isnull().any()]"  à donner le coulone où il y a des valeurs manquant par contre la commende ""data.isnull().count()"" a donner tout les coulones n'ont pas des valeurs manquant

# %% [markdown]
# au dessous on va visualiser les valeur aberantes à l'aide de la bibliotheque seaborn

# %%
sns.set(style='whitegrid')
ax=sns.boxplot(data=data['bmi'],orient='h')

# %% [markdown]
# au dessous on calcule borne inf de la box

# %%
Q1=data['bmi'].quantile(0.25)
print(Q1)
# Out:
# 23.5

# %% [markdown]
# au dessous on calcule borne sup de la box

# %%
Q3=data['bmi'].quantile(0.75)
print(Q3)
# Out:
# 33.1

# %% [markdown]
# au dessous on calcule le moyenne de la box

# %%
"""Q2=data['bmi'].quantile(0.50)
print(Q2)"""
# Out:
# "Q2=data['bmi'].quantile(0.50)\nprint(Q2)"

# %%
print((Q1+Q3)/2)
# Out:
# 28.3

# %% [markdown]
# au dessous on calcule l'inf de l'axe

# %%
IQR=Q3-Q1
inf=Q1-1.5*IQR

# %% [markdown]
# au dessous on calcule LE SUP de l'axe

# %%
IQR=Q3-Q1
sup=Q3+1.5*IQR

# %% [markdown]
# au dessous on counté les valeurs aberantes

# %%
data[data['bmi']>sup].count()
# Out:
# id                   110
# gender               110
# age                  110
# hypertension         110
# heart_disease        110
# ever_married         110
# work_type            110
# Residence_type       110
# avg_glucose_level    110
# bmi                  110
# smoking_status       110
# stroke               110
# dtype: int64

# %% [markdown]
# au dessous on visualise l'avrage de la glucemie par rapport age à l'aide de la bibliotheque matplotlib

# %%
plt.scatter(x=data['age'],y=data['avg_glucose_level'])
plt.xlabel('Age')
plt.ylabel('MOYENNE DU GLYCEMIE')
# Out:
# Text(0, 0.5, 'MOYENNE DU GLYCEMIE')

# %% [markdown]
# au dessous on visualise les different schema de different coloumn à l'aide de la bibliotheque seaborn

# %%
sns.set(style='ticks')
sns.pairplot(data)

# %% [markdown]
# au dessous on va extraire les valeurs indépendantes de bmi

# %%
x=data.iloc[:,9]
print(x)
# Out:
# 0       36.6
# 1        NaN
# 2       32.5
# 3       34.4
# 4       24.0
#         ...
# 5105     NaN
# 5106    40.0
# 5107    30.6
# 5108    25.6
# 5109    26.2
# Name: bmi, Length: 5110, dtype: float64

# %% [markdown]
# au dessous on va extraire les valeurs dépendantes de bmi

# %%
y=data.iloc[:,9].values
print(y)
# Out:
# [36.6  nan 32.5 ... 30.6 25.6 26.2]

# %% [markdown]
# # cleaning data
# on remplacer les valeurs manquant (Nan,-0.9999999999,-1,-99,np.nan,np.inf) par le module Imputer

# %%
from sklearn.preprocessing import Imputer
Imputer = Imputer( missing_data='NaN',strategy='mean',axis=0)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-90-2650688305bb> in <module>
# ----> 1 from sklearn.preprocessing import Imputer
#       2 Imputer = Imputer( missing_data='NaN',strategy='mean',axis=0)
#
# ImportError: cannot import name 'Imputer' from 'sklearn.preprocessing' (D:\Anaconda\lib\site-packages\sklearn\preprocessing\__init__.py)
